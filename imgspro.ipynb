# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Flatten, Conv2D, MaxPooling2D # new!
from PIL import Image
import os
#importing the libraries

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Image Proccesing

# %%
path2 = r'C:\Users\henri\dsci478k\data\monet_jpg'

training_data= []
for img in os.listdir(path2):
    pic = cv2.imread(os.path.join(path2,img))
    pic = cv2.cvtColor(pic,cv2.COLOR_BGR2RGB)
    pic = cv2.resize(pic,(80,80))
    training_data.append([pic])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17912/1004552251.py in <module>
#       4 for img in os.listdir(path2):
#       5     pic = cv2.imread(os.path.join(path2,img))
# ----> 6     pic = cv2.cvtColor(pic,cv2.COLOR_BGR2RGB)
#       7     pic = cv2.resize(pic,(80,80))
#       8     training_data.append([pic])
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
plt.imshow(np.array(training_data[0]).reshape(80,80,3))

# %%
path2 = r'C:\Users\henri\dsci478k\data\photo_jpg'

training_datapic= []
for img in os.listdir(path2):
    pic = cv2.imread(os.path.join(path2,img))
    pic = cv2.cvtColor(pic,cv2.COLOR_BGR2RGB)
    pic = cv2.resize(pic,(80,80))
    training_datapic.append([pic])

# %%
plt.imshow(np.array(training_datapic[1]).reshape(80,80,3))
